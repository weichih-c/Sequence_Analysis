# %%
# check if hooklogs files are error
import os
import shutil
hooklogDir = 'data/hooklogs/'
failHooklog = 'data/fail_hooklogs/'

for fileHook in os.listdir(hooklogDir):
    with open(hooklogDir+fileHook, "r") as f:
        first = f.readline() 
        
        if first:                 
            first = first.split()[1]
            f.seek(-2, 2)             # Jump to the second last byte.
            while f.read(1) != b"\n": # Until EOL is found...
                f.seek(-2, 1)         # ...jump back the read byte plus one more.
            lastOri = f.readline()
            last = lastOri.split('=')[0].split('\n')[0]
            
#             if not ( '.exe' in first or '.tmp' in first):
#                 print fileHook, ": ", first, "-", lastOri
            if last!='Return' and last!='ExitProcess' :
                print fileHook, ": ", first, "-", lastOri,
        else:
            shutil.move(hooklogDir+fileHook, failHooklog)
            print fileHook, ": ","empty\n"
# Out:
# ff93d98dcbb9e143b3652ad10c1892b0_IE_3200.trace.hooklog :  IEXPLORE.EXE - data=image/gif
# fffeab12697deecd6e76640a3a57b700_3172.trace.hooklog :  malware.exe - dwThreadId=3216
# ffea985b9cb20ec5dc60139ffff29d10_3176.trace.hooklog :  malware.exe - dwThreadId=3220
# ffff653512ab48ebc0351515ad934ac0_3236.trace.hooklog :  malware.exe - dwThreadId=3288
# fff86a9c3eac29a3f5361a05cb919190_2984.trace.hooklog :  malware.exe - dwThreadId=3080
# ffff2915f8f4ae0b7de3cbbd88dd3a40_2984.trace.hooklog :  calc.exe - dwThreadId=3012
# ffff948db69f1d5369a5f01462b40030_3052.trace.hooklog :  malware.exe - dwThreadId=3088
# ffdc8fe47c2f984ac21abe18b4005943_3264.trace.hooklog :  malware.exe - data=0
# bc7f15b89bbd891f95425abb4f3b8c30_3292.trace.hooklog :  net.exe - dwThreadId=3424
# 0c494687e1a01a7e3eefc541f0a91d50_3304.trace.hooklog :  net.exe - dwThreadId=3472
# fffb7db0b4b343eba03ec29ff81410b0_3240.trace.hooklog :  malware.exe - dwThreadId=3276
# ffe6ff3bc571034e680d824eb9f97670_3340.trace.hooklog :  malware.exe - dwThreadId=3352
# fb9ad9b1c5a2e24a61735895690849a0_3320.trace.hooklog :  bot1.exe - data=C:\WINDOWS\system32\userinit.exe,C:\WINDOWS\system\bot1.exe,
# fffc0eed416e6137d966ce8151e31f90_3168.trace.hooklog :  malware.exe - dwThreadId=3212
# ff07a4eccc209b35c5b0d5eee38d96c0_3304.trace.hooklog :  Ekecdikl.exe - TerminateProcess
# ffa0fa4008da77739bd046a1c0cc3290_2840.trace.hooklog :  malware.exe - dwThreadId=2872
# fffed6c63f8c3a14238bcf78c80cca10_3160.trace.hooklog :  malware.exe - dwThreadId=3180
# ff90e2b30134aa53546775a8ccc62e60_3064.trace.hooklog :  malware.exe - dwThreadId=3136
# ffa1dbac37eb1ae37414f3e89e9cef70_3160.trace.hooklog :  malware.exe - dwThreadId=3180
# fff669f3bb3ec4c7ae6ad373cf42d2e0_3292.trace.hooklog :  picture.exe - data=0
# fb9ad9b1c5a2e24a61735895690849a0_1800.trace.hooklog :  explorer.exe - data=16
# ffe81468aacf1a62c9f58f2defd9f130_3004.trace.hooklog :  malware.exe - procName=malware.exe
# fff98513f7dc548029ff5e741b7569c0_3196.trace.hooklog :  malware.exe - dwThreadId=3216
# fff7dcb3463f5f99f158b0485113b850_3032.trace.hooklog :  malware.exe - dwThreadId=3068
# fffaf4cd258eb7957e6931b5196fecf0_3152.trace.hooklog :  malware.exe - dwThreadId=3192
# 0c494687e1a01a7e3eefc541f0a91d50_3264.trace.hooklog :  net.exe - dwThreadId=3404
# fff6da05279f6909e0c5445612c6bfc0_3132.trace.hooklog :  malware.exe - dwThreadId=3172
# ff4c85a4c95549ff240192ac07cf1ba0_3256.trace.hooklog :  malware.exe - dwThreadId=3280
# fffa14684ec37491be14e18c73ffeb80_2812.trace.hooklog :  malware.exe - dwThreadId=2836
# ffe567f1bef57fbef02d9447c5ea66a0_3252.trace.hooklog :  services.exe - data=
# ffef875bf562e66219a808f925ac3340_3120.trace.hooklog :  malware.exe - dwThreadId=3208
# fffc4faedbf0a97b03f1ec4c4f277fe0_3108.trace.hooklog :  Lalikfmn.exe - TerminateProcess
# ffdf141aded498e641b45b0e2188e360_3184.trace.hooklog :  Hkhagd32.exe - TerminateProcess
# ffff14b75aff6098a07c30d75a4deae0_3116.trace.hooklog :  malware.exe - dwThreadId=3160
# ffa3579999cd64f196c5a85e62163fc0_IE_3192.trace.hooklog :  IEXPLORE.EXE - data=Apartment
# fffd28bc956b4adf388e1550d51a60f0_3080.trace.hooklog :  malware.exe - dwThreadId=3128
# fff850f5b60617e3a9bcda5c4af4c9a0_3176.trace.hooklog :  malware.exe - dwThreadId=3224
# ffdbd2c8c2d7c3d02690378ac30fb170_3256.trace.hooklog :  malware.exe - dwThreadId=3332
# ff93d98dcbb9e143b3652ad10c1892b0_3188.trace.hooklog :  malware.exe - dwThreadId=192
# ffe634543a6589f670653ee17dd2a3d0_1568.trace.hooklog :  explorer.exe - data=ants-3321da9da7
# fffc62a185e4e5e048884d1cffc02ad0_3272.trace.hooklog :  malware.exe - dwThreadId=3328

# %%
# # automatically copy files for every family 
# import pickle
# import shutil 
# import os

# parameter = True
# windows = 1
# upgma_threshold = 0.40
# group_member_limit = 6
# tag = '484'
# group_member_file_name = "upgma-%s-%s-w%d-t%0.2f-gm%d.pickle" % (
#     tag, 'par' if parameter else 'nopar', windows, upgma_threshold, group_member_limit)

# with open('pickle/'+group_member_file_name, 'rb') as f:
#     data = pickle.load(f)
# if f: f.close()
    
# with open('pickle/av_list-mal_dict-family_dist.pickle', 'rb') as o:
#     data_family = pickle.load(o)
# if o: o.close()

# group_family_file_name = "groupFamily-%s-%s-w%d-t%0.2f-gm%d.csv" % (
#     tag, 'par' if parameter else 'nopar', windows, upgma_threshold, group_member_limit)
# o = open('output/'+group_family_file_name, 'w')    
    
# for i in data:    
#     print i
#     o.write('%s\n'% i)
#     for f in data[i][1]:
#         o.write(',%s,%s\n'% ( f,data_family[f.split('_')[0]]))
#         print f,data_family[f.split('_')[0]]
# if o: o.close()

# %%
# automatically copy files for every family 
import pickle
import shutil 
import os
# print(os.path.isdir("/home/el"))
# print(os.path.exists("/home/el/myfile.txt"))

data_path='data/family/'

parameter = True
windows = 1
upgma_threshold = 0.4
group_member_limit = 6
tag = '484'
group_member_file_name = "upgma-%s-%s-w%d-t%0.2f-gm%d.pickle" % (
    tag, 'par' if parameter else 'nopar', windows, upgma_threshold, group_member_limit)

with open('pickle/'+group_member_file_name, 'rb') as f:
    data = pickle.load(f)
    
for i in data:    
    print i
    family_path = data_path+str(i)+"_"+str(data[i][0])[1:6]+" ("+str(len(data[i][1]))+")"+"/"+"hooklogs/"
    if not os.path.isdir(family_path):
        if not os.path.isdir(family_path[0:-len('hooklogs/')]):
            os.makedirs(family_path[0:-len('hooklogs/')])
            os.makedirs(family_path)
        else:
            os.makedirs(family_path)
    for f in data[i][1]:
        file_path = f+".trace.hooklog" 
        print file_path
        if not os.path.isfile(family_path+file_path ):
            shutil.copy('data/hooklogs/'+file_path, family_path+file_path)
# Out:
# 896
# 329a5855e90638c7d25c6a1265d1d74f_3168.trace.hooklog
# 27f00a453f3bdd8a3beb273b3ad2d39d_3212.trace.hooklog
# 32a20d06dc9132648eaead1ca9b1033d_3272.trace.hooklog
# a5b40ff4ca9be61c6295fe8e6b5c7df4_3216.trace.hooklog
# 331f0d1b3e25f7a3921642c26380f09b_3196.trace.hooklog
# a4f4fd555bcbfe6f62725a5599aee941_3096.trace.hooklog
# 84dffc6d32371bbbfa701551e363af30_3212.trace.hooklog
# 23ed4c1867cf18a06fed1b8fa7ec523e_3192.trace.hooklog
# 897
# 6123f4e765d6ba2bb4d9878de8f0598b_3200.trace.hooklog
# 2272d05b959f133bcf3e38c48ddbfcad_3256.trace.hooklog
# c32e9387f94c67a39d4c35b111302b0b_3208.trace.hooklog
# 32abc951d6c707d2036c9e2a50e5fcb6_2868.trace.hooklog
# b295318cdd0ad09baa1cdadf86b90fc1_3228.trace.hooklog
# a0ceb22ed87df9019f39c5c135a58c17_3228.trace.hooklog
# 03c009b451e012002513513a5d7e1b00_3444.trace.hooklog
# 899
# d496a8ddf556a2097f49e780ff26ec38_3240.trace.hooklog
# c1145db43a83fa9721160a9b0ba43a63_3160.trace.hooklog
# 1f2366c3955cf09b599a8a9233367cac_3188.trace.hooklog
# 2872821c2d87ae14a98e0017cffb4434_3132.trace.hooklog
# c5e453ce174407cc2796c5f3444cc2c6_3172.trace.hooklog
# 504084a3a098a94ac2cd6c1d2c6ed357_3092.trace.hooklog
# b435648fcba6306bccc01c50c0785651_3240.trace.hooklog
# 868
# d5036353d1b1b9018c4443442ff8c68b_3216.trace.hooklog
# a0a01b4cf56dee146e3cf4701c203547_3356.trace.hooklog
# a0a01b4cf56dee146e3cf4701c203547_3252.trace.hooklog
# 82cf1e67ed155da7e89fc4f49b97050d_3228.trace.hooklog
# 82cf1e67ed155da7e89fc4f49b97050d_3288.trace.hooklog
# 2a8d402d0698b7d07fbeebce048df50b_3252.trace.hooklog
# c3ea3ad31e662953f0fcd1c62c50b130_3212.trace.hooklog
# 833562ee3e3a2569fe42a303d5619464_3088.trace.hooklog
# 246920c3ec29d419549fadefd78c30e4_3396.trace.hooklog
# 2a3f0f96e4cc7ae13558d80d99426233_3296.trace.hooklog
# 907
# 942a444c928e47cf47454eccbe5da352_3160.trace.hooklog
# 717c6535d2743d25384de477af509559_3280.trace.hooklog
# a1e68c58d8bce6639dd5ec2e4bccb79c_3224.trace.hooklog
# 22f1e10e563130d67bb55961a7271447_3188.trace.hooklog
# 949304663e15ab1dcd9a0781b6d871d8_3148.trace.hooklog
# 25bc7a8af105eb9ac6feb54e16ae741f_3340.trace.hooklog
# da508d53f4f904089d63e059be87e431_3188.trace.hooklog
# d91a6687f9760b20e5aa4e88cf8b18a8_3180.trace.hooklog
# 060c18ffe4b4f8b47c90a2339533d622_3148.trace.hooklog
# 1000511f9f867a3ee51cb91e7d922e99_3256.trace.hooklog
# 81f727efa7f0977b86ed3581e159b219_3156.trace.hooklog
# 902e9898276a9dd149301756092550ce_3228.trace.hooklog
# 22e2fe27211a28c8cc5b67d498824743_3280.trace.hooklog
# 35a94ca04d07c9427c78d1befc431ea6_3252.trace.hooklog
# b2b712a7e0f486a0eddfb412f06a6c21_3064.trace.hooklog
# b3b15c3261e48f4d001b08fc900f40af_3152.trace.hooklog
# 237c4e337993167ea887286c61844807_3152.trace.hooklog
# b0600327e25557f457e477594e3684e6_3016.trace.hooklog
# 24ef90755c68c3f2f6d4f8805615bad6_3244.trace.hooklog
# d1f8897c649bd60080c8b1d7027785d9_3168.trace.hooklog
# c3ec90236977ee3e046c466cbb04d031_3280.trace.hooklog
# a1565742cfdebc0d7b21f2dba34a4c5c_3212.trace.hooklog
# d0aec3d90e153c188c76206a672014b7_3148.trace.hooklog
# 62f6ca088970853ccb2fd794cc65bf65_3308.trace.hooklog
# b5088c9af7eeb7d2d966881a017384b6_3120.trace.hooklog
# a1fd67af4edfb346a8c8abaab5e1cc7b_3128.trace.hooklog
# d8762c8cea86083ce9a3aec9aedb109f_3008.trace.hooklog
# 2ab814305cf1db748057a4bc313fb503_3160.trace.hooklog
# 9271df78c6f33488bae8d9ab82a47440_3200.trace.hooklog
# c3c7402347a313740a7a10edc33cb4c5_3204.trace.hooklog
# a2c9cd82e2c0388d6d4b4dcbd5895a48_3184.trace.hooklog
# d7f83cb68543a60efc18de6afeda3afd_3204.trace.hooklog
# a3512f81f74bab766b8d55d6480ea245_3212.trace.hooklog
# 569db7273547dfb2a0e6016e166bf275_3188.trace.hooklog
# b5a875aee144f95bcefcdb7f6daea440_3224.trace.hooklog
# a49ab036c70167ff9894e142cfd279aa_3280.trace.hooklog
# 06dc60ab51a3ba87757726f7a085d9d5_3176.trace.hooklog
# a26b2ba079e8616c8ce35f3533bc45ec_3140.trace.hooklog
# b768c2760776c66dfed69d4ea0b60d1c_3184.trace.hooklog
# d293b63ea6e67eb88cd85980e25c3642_3188.trace.hooklog
# 170e99072c8840704e784d3ecde647a5_3204.trace.hooklog
# 807090991f3da3c1132f2b5dec7511a3_3220.trace.hooklog
# 1037b8385f3eb7f7ed6cbdf4251b5fa2_3172.trace.hooklog
# b1def3ea5f4f716e30b561cbbfa7dbc7_3032.trace.hooklog
# 0278192ce1aa7f8c4ae746eae73e6475_3204.trace.hooklog
# 263bde02a8c2daa812ae145e9efcda4d_3232.trace.hooklog
# b174b9754af5e723a047b1093d96593b_3152.trace.hooklog
# c16825d05bbb35c0d36120011c6d666f_3192.trace.hooklog
# 519b94ba9a84b4ede97b7478cefacf65_3164.trace.hooklog
# a33580103ea07f5f24cbda7500c28781_3040.trace.hooklog
# 1088046dcb34429d55d4695cf3b28301_3232.trace.hooklog
# 236740b7cbf84cc3e11e009499392313_3164.trace.hooklog
# 913cf9179e7dc56363673a926eaf5b7b_3204.trace.hooklog
# 51c2c4afe76bcd179ba83619b4840c71_3120.trace.hooklog
# 5032e7e1f8cd2a9cee4dba605bb71c39_2812.trace.hooklog
# 324ed762499093ef9cd82d8e346070dc_3088.trace.hooklog
# 909
# d695c2c7d9718238bd95b354a147c775_3128.trace.hooklog
# c55c1627f5bf9fc6d85ea6e8501dbf78_3100.trace.hooklog
# 33ba5ee592067b75ac74aceb66170787_2836.trace.hooklog
# d108622979a9586df24338f535b3f047_3160.trace.hooklog
# 31b164b4dc1d2744bf11183604572648_3200.trace.hooklog
# 17b48167db6bcb087412b8a047446331_3156.trace.hooklog
# 60e777d78106b7f803ee6bf5b74d317d_3244.trace.hooklog
# 7070e73ac6795a8a02270381fcdfb99b_3200.trace.hooklog
# 337da6c8942095e6f1359325676f05ef_3212.trace.hooklog
# 26914ea7c65538ef9954b779ab7dc280_3236.trace.hooklog
# 93c213c3c09cfaf1de11b23469071368_3208.trace.hooklog
# d381dc0651aee234b7d59c06800049c4_3116.trace.hooklog
# 60d3d41ae03d24038520a7dee6a0abbc_3224.trace.hooklog
# 340c63ed7d513d67cf007983d34e6f68_3032.trace.hooklog
# 5169113d8207a5605ff57604a00c030a_2840.trace.hooklog
# a0f2e27b28835c96377b73b007c09f15_3148.trace.hooklog
# 518c227fc67926213502da39d8d44fd6_3184.trace.hooklog
# 811c47bd9f7347318794f59a8230c180_3268.trace.hooklog
# 52cd8c9cc8c4e794e9243d787853f556_3072.trace.hooklog
# 2c05a699fcdd02c4a3e982543363fa44_3256.trace.hooklog
# c408d44ff050d84a6679c88b6c156ca7_3132.trace.hooklog
# a4756d0fb104b86ec1c6cbbb23a2c45b_3228.trace.hooklog
# 2b0d1f7527e0191f190744e8a1e319c3_2828.trace.hooklog
# 31ad1a73583f2d44e741747e4fc4dbe0_3188.trace.hooklog
# 912
# d422d21370469217ba738e5fad136265_3224.trace.hooklog
# 82ec14e682cb0322129fb4e42304962d_3236.trace.hooklog
# 83f04b9aebe38cb456cf68f206b0f688_3288.trace.hooklog
# c1d930795f3c26cbdd2c22df3021c644_3248.trace.hooklog
# b3f691d4f0fe5ac993b75b559046bdd5_3160.trace.hooklog
# 316ec8b680b5376072bff5338c5eae20_3228.trace.hooklog
# d65cd3137858bb17f8b9b7fb0964815f_3148.trace.hooklog
# 815a763f2c764a33094625aedb37d9ef_3280.trace.hooklog
# d16a128f17d909a42dbfe0e396003fad_3084.trace.hooklog
# c40f9f7eea18ede8f0f6ed40f3e8d39e_3148.trace.hooklog
# 802660d278ba369c56a1bc7a31baa265_3148.trace.hooklog
# b32a53310f561ef383c8c4dd3ccb5d1b_3212.trace.hooklog
# 81823bb1c8598eed93c96cab959c2f74_448.trace.hooklog
# 808ab4f1cca8091b05d26f15f775c525_3140.trace.hooklog
# b4ecab3de919dc6f8095a3b462524597_3060.trace.hooklog
# b12e66515990aba2ca11fd4e72959f42_3124.trace.hooklog
# 528360b3ff12866c8de7fb90369cf6a4_3232.trace.hooklog
# 290a6595331647dc0f7b8c20f8ca38a3_3296.trace.hooklog
# d5ebf976acd93ae86bc92b49273ebbd2_3136.trace.hooklog
# b1961865622a279d82ceffa4dc0fc414_3256.trace.hooklog
# 02c27a2e4c215d22fabdfc7b46fd6f20_3300.trace.hooklog
# 34dc911577554e81eee75cfe0fe709ff_3104.trace.hooklog
# 86060592b44f5796e297d495f5aaee4f_3180.trace.hooklog
# 20f246783e49bd5d1d7d90662e97a9e9_3252.trace.hooklog
# b247b6b602fbfeafd096088a56f6ffb9_3152.trace.hooklog
# 819cf75b209768d2083ee84059ec294f_3224.trace.hooklog
# 961bac503db82b784e6f37dd9d0cebf6_3224.trace.hooklog
# 33cc90da028fd1db12c21ac77b6c2532_3280.trace.hooklog
# d67a719d72e33099bcc28e25249e8799_3208.trace.hooklog
# 202cfbaccc16ecbfe4c8f544ebf50ded_3068.trace.hooklog
# c097e3603b5903d6f7c65038d69b7285_3088.trace.hooklog
# b271dbd8ad7519eab3e5e9008013623e_3240.trace.hooklog
# a607dd2dc35f0a24e010756620c19227_3092.trace.hooklog
# 509c649dd40ee219afd6c41e25e38d36_3164.trace.hooklog
# 578adec078a8c12a19ab07a4e64cf3b2_3200.trace.hooklog
# c323aabad606d27b03ca7182cfe66f1a_3252.trace.hooklog
# 7183044ef3d566ed8d109695648ff7f9_3228.trace.hooklog
# 33a6249e0f094d64bda9660f3294c1ba_3064.trace.hooklog
# 347bad094f00c9013f59a07e1647e939_3320.trace.hooklog
# c603502225770041c03fd732837719c8_3148.trace.hooklog
# 55da555e75ab922f7dfcceb1209289b3_3116.trace.hooklog
# 725
# d1f35ba9bee466133d93bf161ad6172b_3152.trace.hooklog
# 52149c30b1c49a7a5a6a9e119b999715_3208.trace.hooklog
# 560ed485d9b62ad9632b8d7d20b266ce_3180.trace.hooklog
# d20135f6ce0705c0f627bd0d40d1448a_3208.trace.hooklog
# 221bdade3f1bd0dd211025fdc859055b_3248.trace.hooklog
# d203e861230e719e0a74031bd55ccd4e_3128.trace.hooklog
# c2b5874fc252386e39b1481b375fd68f_2804.trace.hooklog
# 855
# c55c1627f5bf9fc6d85ea6e8501dbf78_3336.trace.hooklog
# c55c1627f5bf9fc6d85ea6e8501dbf78_3128.trace.hooklog
# c55c1627f5bf9fc6d85ea6e8501dbf78_3288.trace.hooklog
# c55c1627f5bf9fc6d85ea6e8501dbf78_3220.trace.hooklog
# 31b164b4dc1d2744bf11183604572648_3392.trace.hooklog
# 31b164b4dc1d2744bf11183604572648_3336.trace.hooklog
# 31b164b4dc1d2744bf11183604572648_3244.trace.hooklog
# 31b164b4dc1d2744bf11183604572648_3436.trace.hooklog
# 337da6c8942095e6f1359325676f05ef_3380.trace.hooklog
# 337da6c8942095e6f1359325676f05ef_3432.trace.hooklog
# 337da6c8942095e6f1359325676f05ef_3240.trace.hooklog
# 337da6c8942095e6f1359325676f05ef_3320.trace.hooklog
# 5169113d8207a5605ff57604a00c030a_2968.trace.hooklog
# 5169113d8207a5605ff57604a00c030a_3028.trace.hooklog
# 5169113d8207a5605ff57604a00c030a_2872.trace.hooklog
# 5169113d8207a5605ff57604a00c030a_3072.trace.hooklog
# 518c227fc67926213502da39d8d44fd6_3220.trace.hooklog
# 518c227fc67926213502da39d8d44fd6_3380.trace.hooklog
# 518c227fc67926213502da39d8d44fd6_3324.trace.hooklog
# 518c227fc67926213502da39d8d44fd6_3440.trace.hooklog
# 52cd8c9cc8c4e794e9243d787853f556_3100.trace.hooklog
# 52cd8c9cc8c4e794e9243d787853f556_3192.trace.hooklog
# 52cd8c9cc8c4e794e9243d787853f556_3244.trace.hooklog
# 52cd8c9cc8c4e794e9243d787853f556_3292.trace.hooklog
# a4756d0fb104b86ec1c6cbbb23a2c45b_3460.trace.hooklog
# a4756d0fb104b86ec1c6cbbb23a2c45b_3412.trace.hooklog
# a4756d0fb104b86ec1c6cbbb23a2c45b_3348.trace.hooklog
# a4756d0fb104b86ec1c6cbbb23a2c45b_3260.trace.hooklog
# 2b0d1f7527e0191f190744e8a1e319c3_3052.trace.hooklog
# 2b0d1f7527e0191f190744e8a1e319c3_2860.trace.hooklog
# 2b0d1f7527e0191f190744e8a1e319c3_3000.trace.hooklog
# 2b0d1f7527e0191f190744e8a1e319c3_2952.trace.hooklog
# 900
# c55c1627f5bf9fc6d85ea6e8501dbf78_tmp_3324.trace.hooklog
# c55c1627f5bf9fc6d85ea6e8501dbf78_tmp_3116.trace.hooklog
# c55c1627f5bf9fc6d85ea6e8501dbf78_tmp_3280.trace.hooklog
# c55c1627f5bf9fc6d85ea6e8501dbf78_tmp_3212.trace.hooklog
# 337da6c8942095e6f1359325676f05ef_tmp_3424.trace.hooklog
# 31b164b4dc1d2744bf11183604572648_tmp_3328.trace.hooklog
# 31b164b4dc1d2744bf11183604572648_tmp_3232.trace.hooklog
# 337da6c8942095e6f1359325676f05ef_tmp_3312.trace.hooklog
# 337da6c8942095e6f1359325676f05ef_tmp_3364.trace.hooklog
# 337da6c8942095e6f1359325676f05ef_3228.trace.hooklog
# 31b164b4dc1d2744bf11183604572648_tmp_3428.trace.hooklog
# d695c2c7d9718238bd95b354a147c775_tmp_3152.trace.hooklog
# 5169113d8207a5605ff57604a00c030a_tmp_3064.trace.hooklog
# 5169113d8207a5605ff57604a00c030a_tmp_2956.trace.hooklog
# 5169113d8207a5605ff57604a00c030a_tmp_3008.trace.hooklog
# 5169113d8207a5605ff57604a00c030a_tmp_2860.trace.hooklog
# 518c227fc67926213502da39d8d44fd6_tmp_3432.trace.hooklog
# 518c227fc67926213502da39d8d44fd6_tmp_3204.trace.hooklog
# 518c227fc67926213502da39d8d44fd6_tmp_3372.trace.hooklog
# 518c227fc67926213502da39d8d44fd6_tmp_3316.trace.hooklog
# 52cd8c9cc8c4e794e9243d787853f556_tmp_3080.trace.hooklog
# 52cd8c9cc8c4e794e9243d787853f556_tmp_3184.trace.hooklog
# 52cd8c9cc8c4e794e9243d787853f556_tmp_3236.trace.hooklog
# 52cd8c9cc8c4e794e9243d787853f556_tmp_3284.trace.hooklog
# a4756d0fb104b86ec1c6cbbb23a2c45b_tmp_3404.trace.hooklog
# a4756d0fb104b86ec1c6cbbb23a2c45b_tmp_3340.trace.hooklog
# a4756d0fb104b86ec1c6cbbb23a2c45b_tmp_3244.trace.hooklog
# 2b0d1f7527e0191f190744e8a1e319c3_tmp_3044.trace.hooklog
# 2b0d1f7527e0191f190744e8a1e319c3_tmp_2848.trace.hooklog
# 2b0d1f7527e0191f190744e8a1e319c3_tmp_2988.trace.hooklog
# 2b0d1f7527e0191f190744e8a1e319c3_tmp_2944.trace.hooklog
# d108622979a9586df24338f535b3f047_tmp_3184.trace.hooklog
# a4756d0fb104b86ec1c6cbbb23a2c45b_tmp_3452.trace.hooklog
# 31b164b4dc1d2744bf11183604572648_tmp_3384.trace.hooklog
# 890
# c4f1656879c4772eefb301379a510721_3228.trace.hooklog
# d5aafe1af9449d87262a5016f0993d99_3216.trace.hooklog
# 260e166c56a4340962aa2bc2cae3eb43_3224.trace.hooklog
# d2e9862303ae42959b733f11a168e268_3096.trace.hooklog
# 61fd4cac9f5429d14d015e7632e3514a_3284.trace.hooklog
# a2593ed0e66611da58ad2fcdca426cdb_3208.trace.hooklog
# a4207e48739ab4da384acaeebcba0c66_3184.trace.hooklog
# 225a739c4a77c0851f5486f6208ef5b7_3200.trace.hooklog
# d0c4bba46e68e0ff5efce1297faa3b49_3200.trace.hooklog
# d2276a5243924db8aac9fb6f0a3bd408_3340.trace.hooklog
# 84870116484818d0428a2303dabdd37b_3216.trace.hooklog
# 27546542eea38e818e2ac51d4ec9775f_3304.trace.hooklog
# 27f348177560314182f161d9ee90b999_3188.trace.hooklog
# 3002038e55383b4e1d14abc7182a1e78_3260.trace.hooklog
# c121f821dc6853574777f3bdf6a68c5a_3168.trace.hooklog
# b77f1865e955be2b1ffe866f54d2b261_3164.trace.hooklog
# 930bc9f36310286d105c318a96264eba_3140.trace.hooklog
# 28e17f1e110f3508ceb611839986a4f4_3208.trace.hooklog
# 81c2d13624f473c10f9866dee8ce79fb_3172.trace.hooklog
# 90489a23cb732ae082adf3def0b5d243_3272.trace.hooklog
# 940f7e9ab19be7a9ce0008a6e6b01f9f_3256.trace.hooklog
# 895
# d422d21370469217ba738e5fad136265_3200.trace.hooklog
# 90bc59dafe96c97402785b619dcfdd21_3276.trace.hooklog
# 407ced5a43dbf4610acd2441ba62e125_3144.trace.hooklog
# a30bbae84906c52d3f3c156994e58843_3240.trace.hooklog
# 249e49943601cb7182c7cf47b37a8598_3268.trace.hooklog
# c181c5ad7bee8a1f0e87bf31701c8a43_3100.trace.hooklog
# 316ec8b680b5376072bff5338c5eae20_3164.trace.hooklog
# d65cd3137858bb17f8b9b7fb0964815f_3128.trace.hooklog
# 32abc951d6c707d2036c9e2a50e5fcb6_2808.trace.hooklog
# 961bac503db82b784e6f37dd9d0cebf6_3192.trace.hooklog
# c40f9f7eea18ede8f0f6ed40f3e8d39e_3120.trace.hooklog
# 33cc90da028fd1db12c21ac77b6c2532_3256.trace.hooklog
# d411eb6d3dd126922f1e18122ea2e346_3136.trace.hooklog
# 03c009b451e012002513513a5d7e1b00_3300.trace.hooklog
# b32a53310f561ef383c8c4dd3ccb5d1b_3180.trace.hooklog
# 53d5d20ac42c9e42d55b9a9dcc3fc344_3140.trace.hooklog
# b271dbd8ad7519eab3e5e9008013623e_3216.trace.hooklog
# 8523f5ace7369187b1f55c2066a82836_3200.trace.hooklog
# c223ce8475dad31d490377183fe057be_3236.trace.hooklog
# c223ce8475dad31d490377183fe057be_3132.trace.hooklog
# c097e3603b5903d6f7c65038d69b7285_3072.trace.hooklog
# 70e399acca62e88cc86d9d3dc0eb50fe_2832.trace.hooklog
# 808ab4f1cca8091b05d26f15f775c525_3120.trace.hooklog
# 83f04b9aebe38cb456cf68f206b0f688_3248.trace.hooklog
# 55da555e75ab922f7dfcceb1209289b3_3088.trace.hooklog
# b4ecab3de919dc6f8095a3b462524597_3020.trace.hooklog
# b10f6b10bd09dec312300bae2214e183_3088.trace.hooklog
# a429bfdadd70794a59885fe2a53dd6ee_3200.trace.hooklog
# d7ce189248c81102a9a4e7ba74a146f8_3256.trace.hooklog
# 305303294ae289f97ceacc37112afcba_3072.trace.hooklog
# 290a6595331647dc0f7b8c20f8ca38a3_3264.trace.hooklog
# 32ce3a2536052169e1ec9be6f493d92c_3272.trace.hooklog
# 2272d05b959f133bcf3e38c48ddbfcad_3208.trace.hooklog
# c32e9387f94c67a39d4c35b111302b0b_3140.trace.hooklog
# b1961865622a279d82ceffa4dc0fc414_3224.trace.hooklog
# 707e73f2f46c9bf3afca84e05b895862_3228.trace.hooklog
# c2118c4184e53db52b1ba3d58ffe15f6_3256.trace.hooklog
# 9141498693d7df7a60b1894ca6417fcd_3244.trace.hooklog
# 7183044ef3d566ed8d109695648ff7f9_3208.trace.hooklog
# b6b51779559b5f20eccc04b0b20bf1fc_3168.trace.hooklog
# c2364137e928f9fd1cd1d62c5b19bd3c_3056.trace.hooklog
# a0ceb22ed87df9019f39c5c135a58c17_3188.trace.hooklog
# 5033a94c6c7dd21d15615ca6d7992147_3340.trace.hooklog
# 32ce3a2536052169e1ec9be6f493d92c_3356.trace.hooklog

# %%
# import pickle
# import os

# # create malware belongs to which group(s)
# parameter = True
# windows = 1
# upgma_threshold = 0.40
# group_member_limit = 6
# tag = '484'
# group_member_file_name = "upgma-%s-%s-w%d-t%0.2f-gm%d.pickle" % (
#     tag, 'par' if parameter else 'nopar', windows, upgma_threshold, group_member_limit)

# with open('pickle/'+group_member_file_name, 'rb') as f:
#     data = pickle.load(f)
# if f: f.close()
    
# data2Fami_dict = {}
# for i in data :
#     for hook in data[i][1]:
#         data2Fami_dict[hook] = i

# data2Fami_list_dict={}
# for hook in data2Fami_dict:
#     mal = hook.split('_')[0]
#     if mal not in data2Fami_list_dict:
#         mal_list = filter(lambda x: mal in x,data2Fami_dict) 
#         malFami_list = [data2Fami_dict[h] for h in mal_list]
#         data2Fami_list_dict[mal] = sorted(malFami_list)

        
# # every members of a group belong to which family and may belongs to many group
    
# with open('pickle/av_list-mal_dict-family_dist.pickle', 'rb') as o:
#     data_family = pickle.load(o)
# if o: o.close()

# group_family_file_name = "groupFamily-%s-%s-w%d-t%0.2f-gm%d.csv" % (
#     tag, 'par' if parameter else 'nopar', windows, upgma_threshold, group_member_limit)
# o = open('output/'+group_family_file_name, 'w')    
    
# for i in data:    
#     print i
#     o.write('%s\n'% i)
#     for f in data[i][1]:
#         mal = f.split('_')[0]
#         o.write(',%s,%s,%s\n'% ( f,data_family[mal], data2Fami_list_dict[mal]))
#         print f,data_family[f.split('_')[0]]
# if o: o.close()

# %%
import pickle
import os

# create malware belongs to which group(s)
parameter = True
windows = 1
upgma_threshold = 0.4
group_member_limit = 6
tag = '1281'
group_member_file_name = "upgma-%s-%s-w%d-t%0.2f-gm%d.pickle" % (
    tag, 'par' if parameter else 'nopar', windows, upgma_threshold, group_member_limit)

with open('pickle/'+group_member_file_name, 'rb') as f:
    data = pickle.load(f)
if f: f.close()
    
data2Fami_dict = {}
for i in data :
    for hook in data[i][1]:
        data2Fami_dict[hook] = i

data2Fami_list_dict={}
for hook in data2Fami_dict:
    mal = hook.split('_')[0]
    if mal not in data2Fami_list_dict:
        mal_list = filter(lambda x: mal in x,data2Fami_dict) 
        malFami_list = [data2Fami_dict[h] for h in mal_list]
        data2Fami_list_dict[mal] = sorted(malFami_list)

        
# every members of a group belong to which family and may belongs to many group
    
with open('pickle/av_list-mal_dict-family_dist.pickle', 'rb') as o:
    data_family = pickle.load(o)
if o: o.close()

group_family_file_name = "groupFamily-%s-%s-w%d-t%0.2f-gm%d.csv" % (
    tag, 'par' if parameter else 'nopar', windows, upgma_threshold, group_member_limit)
o = open('output/'+group_family_file_name, 'w')    

fami2group_dict = {} #========== 10/3
fami2group_dict_fin = {} #==========10/4
dataFami_num = {} #==========10/4
for i in sorted(data):    
    fami2group_dict_fin[i] =[]
    fami2group_dict[i]= [] #========== 10/3
    o.write('%s\n'% i)
    for f in data[i][1]:
        mal = f.split('_')[0]
        o.write(',%s,%s,%s\n'% ( f,data_family[mal], data2Fami_list_dict[mal]))
        
        fami2group_dict[i].append(data_family[mal]) #========== 10/3
      
    fami2group_dict[i]= sorted(list(set(fami2group_dict[i]))) #========== 10/3
    for f in fami2group_dict[i]: #==========10/4
        if f not in dataFami_num.keys(): 
            dataFami_num[f]=1
        else:
            dataFami_num[f]= dataFami_num[f] +1     
        fami2group_dict_fin[i].append(f+'_'+str(dataFami_num[f])) #==========10/4
if o: o.close()  
fami2group_dict_fin
# output: data_family, data2Fami_list_dict, fami2group_dict
# Out:
# {1354: ['cimga_1', 'hijacker_1', 'win64_1'],
#  1410: ['lydrak_1'],
#  1719: ['elkern_1', 'sytro_1'],
#  1819: ['eggogka_1'],
#  1821: ['admedia_1',
#   'airinstaller_1',
#   'androm_1',
#   'corrupt_1',
#   'expiro_1',
#   'graybird_1',
#   'kazy_1',
#   'msil_1',
#   'protexor_1',
#   'symmi_1',
#   'virut_1'],
#  1822: ['hhqsieb_1', 'poison_1'],
#  2003: ['infoleak_1',
#   'installerex_1',
#   'installrex_1',
#   'sergeypetr_1',
#   'strictor_1'],
#  2076: ['webber_1'],
#  2114: ['vilsel_1'],
#  2117: ['admedia_2',
#   'androm_2',
#   'corrupt_2',
#   'msil_2',
#   'protexor_2',
#   'symmi_2',
#   'virut_2'],
#  2127: ['agentwdcr_1',
#   'cimga_2',
#   'hijacker_2',
#   'pyddld_1',
#   'small_1',
#   'viking_1'],
#  2146: ['webber_2'],
#  2162: ['gamarue_1', 'loringk_1', 'sillyfdc_1', 'trojandropper_1'],
#  2165: ['kazy_2',
#   'loadmoney_1',
#   'ogiman_1',
#   'rcbbvlei_1',
#   'renos_1',
#   'symmi_3',
#   'tnega_1'],
#  2245: ['hidp2p_1', 'picsys_1', 'pornoasset_1'],
#  2256: ['firseria_1',
#   'fiseria_1',
#   'morstar_1',
#   'mplug_1',
#   'solimba_1',
#   'tnega_2'],
#  2274: ['dcdddsc_1',
#   'lmijlh_1',
#   'r9x9lwfiy_1',
#   'ranpax_1',
#   'ribkrh8o1tciy_1',
#   'ribkrrxxijiiy_1',
#   'rnltkkdiy_1',
#   'tnega_3',
#   'txxktt_1',
#   'urelas_1',
#   'zusy_1'],
#  2282: ['downloadware_1',
#   'fakeav_1',
#   'pincher_1',
#   'soft32download_1',
#   'tnega_4'],
#  2288: ['corrupt_3', 'diple_1', 'genus_1', 'nsis_1', 'vbkrypt_1', 'vobfus_1'],
#  2291: ['ramnit_1', 'spyeye_1', 'virtob_1'],
#  2294: ['cimga_3', 'hijacker_3', 'win64_2'],
#  2303: ['beebone_1',
#   'chinky_1',
#   'click3_1',
#   'dnascan_1',
#   'graftor_1',
#   'inject_1',
#   'jorik_1',
#   'llac_1',
#   'pushdo_1',
#   's1arqpcaf_1',
#   'scar_1',
#   'sillydl_1',
#   'sirefef_1',
#   'vbinject_1',
#   'vbkrypt_2',
#   'vbna_1',
#   'vbran_1',
#   'vilsel_2',
#   'virtool_1',
#   'vobfus_2'],
#  2308: ['cimga_4',
#   'deepscan_1',
#   'firseria_2',
#   'generickd_1',
#   'inject_2',
#   'installbrain_1',
#   'jorik_2',
#   'kazy_3',
#   'rebhip_1',
#   'trojanspy_1',
#   'webber_3',
#   'yakes_1',
#   'zusy_2'],
#  2313: ['agentwdcr_2',
#   'amonetize_1',
#   'artemis_1',
#   'aspxor_1',
#   'autoit_1',
#   'bettersurf_1',
#   'bfvh_1',
#   'bgkr_1',
#   'bgoj_1',
#   'cimga_5',
#   'delf_1',
#   'gamarue_2',
#   'hijacker_4',
#   'hmnfrb4nrabib_1',
#   'kazy_4',
#   'megasearch_1',
#   'pqkfrvifleaib_1',
#   'pyddld_2',
#   's-7e572cdd_1',
#   'sillyfdc_2',
#   'simbot_1',
#   'small_2',
#   'swiftbrowse_1',
#   'viking_2',
#   'virtool_2',
#   'win64_3',
#   'zusy_3'],
#  2315: ['airinstaller_2', 'bosbot_1', 'installcore_1', 'madang_1'],
#  2319: ['_1',
#   '1clickdownload_1',
#   'amonetize_2',
#   'autoit_2',
#   'babylon_1',
#   'badur_1',
#   'bettersurf_2',
#   'defaulttab_1',
#   'domaiq_1',
#   'ibryte_1',
#   'jatif_1',
#   'kazy_5',
#   'mfcdafd_1',
#   'nsis_2',
#   'outbrowse_1',
#   'pistolar_1',
#   'potentially_1',
#   'reputation_1',
#   'soft32downloader_1',
#   'solimba_2',
#   'somoto_1',
#   'tnega_5',
#   'wpad_i_1'],
#  2320: ['amonetize_3',
#   'bettersurf_3',
#   'firseria_3',
#   's-7e572cdd_2',
#   'swiftbrowse_2',
#   'tnega_6',
#   'vbinject_2',
#   'vobfus_3'],
#  2322: ['fearsomv_1',
#   'firseria_4',
#   'gamepass_1',
#   'graftor_2',
#   'kbautbb_1',
#   's-a036894d_1',
#   'solimba_3'],
#  2323: ['airinstaller_3',
#   'backdoor2_1',
#   'buzy_1',
#   'clkmbpd_1',
#   'dafaiy_1',
#   'emailworm_1',
#   'fignya_1',
#   'hmnfrb4nrabib_2',
#   'ibryte_2',
#   'ipz_1',
#   'ircfast_1',
#   'jatif_2',
#   'juchedk_1',
#   'kazy_6',
#   'loadmoney_2',
#   'mydoom_1',
#   'ogimant_1',
#   'optimuminstaller_1',
#   'otwycal_1',
#   'pqkfrvifleaib_2',
#   'pyddld_3',
#   'ramnit_2',
#   'reputation_2',
#   'sdbot_1',
#   'small_3',
#   'spammer_1',
#   'spyware_1',
#   'strictor_2',
#   'symmi_4',
#   'tnega_7',
#   'trojan-spy_1',
#   'zbotk_1'],
#  2327: ['jstpee_1'],
#  2328: ['firseria_5',
#   'generickd_2',
#   'spyware_2',
#   'tnega_8',
#   'urelas_2',
#   'zbotk_2'],
#  2329: ['a-40c0358e_1',
#   'bceeu_1',
#   'botnet_1',
#   'dfjscb_1',
#   'graftor_3',
#   'kazy_7',
#   'mplug_2',
#   'multiplug_1',
#   'tnega_9',
#   'worm_agent_1'],
#  2331: ['androm_3',
#   'cimga_6',
#   'delf_2',
#   'firseria_6',
#   'fiseria_2',
#   'gamarue_3',
#   'generickd_3',
#   'genus_2',
#   'graftor_4',
#   'gupboot_1',
#   'hijacker_5',
#   'jkdqled_1',
#   'kazy_8',
#   'killproc_1',
#   'llac_2',
#   'megasearch_2',
#   'memscan_1',
#   'morstar_2',
#   'mplug_3',
#   'rebhip_2',
#   's1arqpcaf_2',
#   'solimba_4',
#   'tnega_10',
#   'vobfus_4',
#   'win64_4',
#   'worm_agent_2',
#   'zbotk_3'],
#  2332: ['cimga_7',
#   'digitalplu8_1',
#   'domaiq_2',
#   'installcore_2',
#   'obfuscated_1',
#   'softpulse_1',
#   'symmi_5',
#   'vilsel_3',
#   'vobfus_5'],
#  2334: ['ipz_2',
#   'kazy_9',
#   'megasearch_3',
#   'multiplug_2',
#   'pyddld_4',
#   'small_4',
#   'trojan-spy_2',
#   'wapomi_1'],
#  2335: ['artemis_2',
#   'aspxor_2',
#   'bfvh_2',
#   'bgkr_2',
#   'kazy_10',
#   'memscan_2',
#   'somoto_2'],
#  2336: ['domainiq_1',
#   'domal_1',
#   'loringk_2',
#   'softpulse_2',
#   'trojandropper_2',
#   'vjadtre_1'],
#  2337: ['buzy_2', 'juchedk_2', 'kazy_11'],
#  2338: ['amonetize_4',
#   'installcore_3',
#   'kazy_12',
#   'megasearch_4',
#   'memscan_3',
#   'multiplug_3',
#   'spyware_3',
#   'tnega_11',
#   'vjadtre_2',
#   'wapomi_2',
#   'zusy_4'],
#  2339: ['agentwdcr_3',
#   'bgoj_2',
#   'debris_1',
#   'domainiq_2',
#   'fearsomv_2',
#   'gamarue_4',
#   'hidp2p_2',
#   'honret_1',
#   'kazy_13',
#   'kbautbb_2',
#   'mfcdafd_2',
#   'msil_3',
#   'pondfull_1',
#   'sprotector_1',
#   'spyware_4',
#   'swiftbrowse_3',
#   'trojan-spy_3',
#   'trojanpws_1',
#   'virlock_1'],
#  2340: ['bfpt_1', 'fraudtool_1', 'kazy_14', 'trojan-spy_4', 'yakes_2'],
#  2341: ['detox_1', 'rmid_1', 'soltern_1', 'sytro_2', 'sytroa_1'],
#  2342: ['badur_2',
#   'bkdr_b_1',
#   'bosbot_2',
#   'gael_1',
#   'horse_1',
#   'llac_3',
#   'ramnit_3',
#   'sisron_1',
#   'tnega_12',
#   'virlock_2',
#   'virtob_2']}

# %%
# automatically build based sample table
import pickle
import os
import csv
import re

data_path='data/family/'

parameter = True
windows = 1
upgma_threshold = 0.4
group_member_limit = 6
tag = '1281'
group_member_file_name = "upgma-%s-%s-w%d-t%0.2f-gm%d.pickle" % (
    tag, 'par' if parameter else 'nopar', windows, upgma_threshold, group_member_limit)
totalAnalysis_path = 'analysis_'+tag+'.csv'

with open('pickle/'+group_member_file_name, 'rb') as f:
    data = pickle.load(f)
    
o = open(totalAnalysis_path, 'w')

# title
o.write('%s,%s,%s,%s,%s,' % ('family', 'group','# sample', '# process_In', '# process_Out')) #========== 10/3
o.write('%s,%s,%s,%s,' % ('# stage','# identical motif','# common motif', '# motiAPIcalls')) #======
o.write('%s,%s,%s\n' % ('# resource','def chain >= 4','top behavior'))

# for k,v in reversed(sorted(resFreq_dist.items(), key=lambda (k,v): v[0])):

family_dist = {}
totalHook_list = os.listdir("data/hooklogs/")
malFamPath_list = os.listdir("data/family/")
for i in sorted(data):
    print i
    # find famiName ==========10/3
    famiName = str(fami2group_dict_fin[i]).replace(',', '-') #==========10/4
    
    # find sampleNum, hookNum,procNum 
    mal_list = []
    total_proc = 0
    for f in data[i][1]:
        hookNum =  len(data[i][1]) # hookNum
        mal = f.split('_')[0]
        if mal not in mal_list:
            mal_list.append(mal)
        mal_proc = filter(lambda x: mal in x, totalHook_list) # process of sample
        total_proc = total_proc + len(mal_proc)               # proNum
    
#     if (i==2294 or i==2323 or i==2328 or i==1354 ): 
    if (i==1354 ): 
        o.write('%s,%s,%s,%s,%s\n' % ( famiName, i, len(mal_list), hookNum, total_proc)) #==========10/3
        continue #======================================================2062 error
    if i == 2294: hookNum = 10
    if i == 2328: hookNum = 17
    if i == 2323: hookNum = 51
    
    # find stageNum, idMotiNum, comMotiNum, motiAPIcalls
    mal_fam_path = filter(lambda x: str(i)+"_" in x, malFamPath_list) 
    malFamDetail_list = os.listdir("data/family/"+'/'+mal_fam_path[0])
    stageMoti_path = filter(lambda x: "stageMoti.csv" in x, malFamDetail_list) 
    with open("data/family/"+'/'+mal_fam_path[0]+'/'+stageMoti_path[0], 'rb') as stageMoti:
        reader = csv.reader(stageMoti)
        stageMoti_list = list(reader)
    stageNum = len(filter(lambda x: 'stage' in x, stageMoti_list[0]))         # stageNum
    motifNum = str(filter(lambda x: 'Motif' in x, stageMoti_list[hookNum+1])) 
#     if i == 2294:
#         print stageMoti_list[hookNum+1]
#         print stageNum
#         print 'mot:', motifNum
    idMotiNum = re.sub('[^0-9]','', motifNum.split(':')[1])  # idMotiNum
    comMotiNum = re.sub('[^0-9]','', motifNum.split(':')[2]) # comMotiNum
    apiMotiNum = re.sub('[^0-9]','', motifNum.split(':')[1])  # idMotiNum   #======
    if stageMoti: stageMoti.close
        
    # find resNum
    totalRes_path = filter(lambda x: "totalRes.csv" in x, malFamDetail_list)
    with open("data/family/"+'/'+mal_fam_path[0]+'/'+totalRes_path[0], 'rb') as totalRes:
        reader = csv.reader(totalRes)
        totalRes_list = list(reader)
    resNum = totalRes_list[-1][1]  # resNum
    if totalRes: totalRes.close
    
    family_dist[i] = [len(mal_list), hookNum, total_proc, # sampleNum, hookNum,procNum 
                     stageNum, idMotiNum, comMotiNum, apiMotiNum, # stageNum, idMotiNum, comMotiNum  #======
                     resNum]  # resNum
    
    # family name_tmp
    if "tmp" in mal_fam_path[0]:
        i = 'tmp_' + str(i) 
    
    o.write('%s,%s,%s,%s,%s,' % ( famiName, i, len(mal_list), hookNum, total_proc)) #==========10/3
    o.write('%s,%s,%s,%s,' % ( stageNum, idMotiNum, comMotiNum, apiMotiNum ))  #======
    o.write('%s,%s,%s\n' % ( resNum,'',''))
if o: o.close()
# Out:
# 1354
# 1410
# 1719
# 1819
# 1821
# 1822
# 2003
# 2076
# 2114
# 2117
# 2127
# 2146
# 2162
# 2165
# 2245
# 2256
# 2274
# 2282
# 2288
# 2291
# 2294
# 2303
# 2308
# 2313
# 2315
# 2319
# 2320
# 2322
# 2323
# 2327
# 2328
# 2329
# 2331
# 2332
# 2334
# 2335
# 2336
# 2337
# 2338
# 2339
# 2340
# 2341
# 2342
