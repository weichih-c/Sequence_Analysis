# %% [markdown]
# ### Hooklog to XML file###
# for paper or human only

# %%
import os
# dir case
hooklog_dir = 'data/hooklogs/'
hooklog_list = next(os.walk(hooklog_dir))[2]

# single case
#hooklog_dir = 'data/094dfb4cdae0efa30b19a82138a80c7d/'
#hooklog_list = list()
#hooklog_list.append('094dfb4cdae0efa30b19a82138a80c7d_1564.trace.hooklog')

# %%
print len(hooklog_list)
print hooklog_list
# Out:
# 3
# ...

# %%
# %run classes/Hooklog.ipynb

# %%
print zip(range(len(hooklog_list)),hooklog_list)
# Out:
# [(0, '0006dfb19193ff5910b3ffc94a29a7f6_1416.trace.hooklog'), (1, '0278192ce1aa7f8c4ae746eae73e6475_1484.trace.hooklog'), (2, '02c27a2e4c215d22fabdfc7b46fd6f20_1536.trace.hooklog'), (3, '02fbfeafd096088a56f6ffb9_1380.trace.hooklog'), (4, '03ae42959b733f11a168e268_1264.trace.hooklog'), (5, '03ae42959b733f11a168e268_1332.trace.hooklog'), (6, '03c009b451e012002513513a5d7e1b00_1280.trace.hooklog'), (7, '03c009b451e012002513513a5d7e1b00_604.trace.hooklog'), (8, '043121379d4a5f0f227d74ef0336428c_1636.trace.hooklog'), (9, '060c18ffe4b4f8b47c90a2339533d622_1568.trace.hooklog'), (10, '0776c66dfed69d4ea0b60d1c_1504.trace.hooklog'), (11, '08261732bfcae9a06c7fd6e6f76b2a81_1100.trace.hooklog'), (12, '08261732bfcae9a06c7fd6e6f76b2a81_1300.trace.hooklog'), (13, '08261732bfcae9a06c7fd6e6f76b2a81_884.trace.hooklog'), (14, '0e153c188c76206a672014b7_992.trace.hooklog'), (15, '0f561ef383c8c4dd3ccb5d1b_1348.trace.hooklog'), (16, '0f561ef383c8c4dd3ccb5d1b_1376.trace.hooklog'), (17, '1036837a1c94b6568a65960
# ...

# %%
# print XML from hooklog_list
index = 0
xml = HooklogXml(hooklog_dir + hooklog_list[index])
xml.printXml()
# Out:
# <?xml version="1.0"?>
# <Profile>
# <Meta>
# <Hash>0006dfb19193ff5910b3ffc94a29a7f6</Hash>
# <Process_Id>1416</Process_Id>
# </Meta>
# <Execution>
# <LoadLibrary lpFileName="WININET.dll" Return="SUCCESS" Time="235140000" />
# <LoadLibrary lpFileName="advapi32.dll" Return="SUCCESS" Time="237690000" />
# <LoadLibrary lpFileName="kernel32.dll" Return="SUCCESS" Time="238830000" />
# <LoadLibrary lpFileName="advapi32.dll" Return="SUCCESS" Time="239360000" />
# <RegQueryValue hKey="HKEY_LOCAL_MACHINE\SYSTEM\CurrentControlSet\Control\Session Manager\CriticalSectionTimeout" Return="SUCCESS" Time="242610000" />
# <RegQueryValue hKey="HKEY_LOCAL_MACHINE\Software\Microsoft\Ole\RWLockResourceTimeOut" result="FAILURE" Time="242610000" />
# <LoadLibrary lpFileName="comctl32.dll" Return="SUCCESS" Time="243280000" />
# <CreateFile hName="C:\WINDOWS\WindowsShell.Manifest" desiredAccess="GENERIC_READ" creationDisposition="OPEN_EXISTING" Return="SUCCESS" Time="244600000" />
# ...
